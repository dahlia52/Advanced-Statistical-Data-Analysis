# %% [markdown]
# <a href="https://colab.research.google.com/github/dahlia52/Advanced-Statistical-Data-Analysis/blob/main/LeNet_cifar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision.transforms as transforms
from torchvision.datasets import MNIST, CIFAR10, CIFAR100
from torch.utils.data import DataLoader

import numpy as np
import matplotlib.pyplot as plt

# %%
path = './datasets/'

transform = transforms.Compose([transforms.ToTensor()]) # 이미지를 텐서로 변환

# Prepare Data
train_data = CIFAR100(root = path, train = True, transform = transform, download = True)
test_data = CIFAR100(root = path, train = False, transform = transform, download = True)

batch_size = 100

# DataLoader
train_loader = DataLoader(dataset = train_data, batch_size = batch_size, shuffle = True, num_workers = 4)
test_loader = DataLoader(dataset = test_data, batch_size = batch_size, shuffle = False, num_workers = 4)

print(train_data)
print(test_data)

input_shape = train_data[0][0].shape # (3,32,32)
output_shape = len(train_data.classes) # 100

print(input_shape,output_shape)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Dataset CIFAR100
#     Number of datapoints: 50000
#     Root location: ./datasets/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )
# Dataset CIFAR100
#     Number of datapoints: 10000
#     Root location: ./datasets/
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )
# torch.Size([3, 32, 32]) 100

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps:0")
elif torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = torch.device("cpu:0")

print(device)
# Out:
# cuda:0

# %%
from torch.nn.modules.activation import LeakyReLU
class LeNet(nn.Module):
  def __init__(self):
    super().__init__()

    self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 18, kernel_size = (5,5), stride = 1, padding = 2) # MNIST 데이터는 흑백 데이터이므로 in_channels = 1
    self.pool1 = nn.AvgPool2d(kernel_size = (2,2), stride = 2, padding = 0)
    self.conv2 = nn.Conv2d(in_channels = 18, out_channels = 48, kernel_size = (5,5), stride = 1) # kernel의 가로, 세로 길이가 동일하므로 kernel_size = 5도 가능
    self.pool2 = nn.AvgPool2d(kernel_size = (2,2), stride = 2, padding = 0)
    self.flatten = nn.Flatten()
    self.fcs = nn.Sequential(
        nn.Linear(1728, 512),
        nn.LeakyReLU(),
        nn.Dropout(),
        nn.Linear(512, 256),
        nn.LeakyReLU(),
        nn.Dropout(),
        nn.Linear(256, 128),
        nn.LeakyReLU(),
        nn.Dropout(),
        nn.Linear(128, output_shape)
    )

  def forward(self, x):
    # print(x.shape) # (100,3,32,32) # batch_size = 100
    hidden = F.leaky_relu(self.conv1(x))
    # print(hidden.shape) # (100,18,32,32)
    hidden = self.pool1(hidden)
    # print(hidden.shape) # (100,18,16,16)
    hidden = F.leaky_relu(self.conv2(hidden))
    # print(hidden.shape) # (100,48,12,12)
    hidden = self.pool2(hidden)
    # print(hidden.shape) # (100,48,6,6)
    hidden = self.flatten(hidden)
    # print(hidden.shape) # (100,1728)
    output = self.fcs(hidden)
    # print(output.shape) # (100,100)
    return output

# %%
model = LeNet().to(device)
loss = nn.CrossEntropyLoss(reduction = 'sum')
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3, weight_decay = 1e-3)

# %%
num_epoch = 150
train_loss_list, test_loss_list = list(), list()

for i in range(num_epoch):
  # train
  model.train()

  total_loss = 0
  count = 0

  for batch_idx, (x, y) in enumerate(train_loader):
    x, y = x.to(device), y.to(device)
    y_est = model.forward(x)
    cost = loss(y_est, y)

    total_loss += cost.item()

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    pred = torch.argmax(y_est, dim = -1)
    count += (pred == y).sum().item()

  acc = count / len(train_data)
  avg_loss = total_loss / len(train_data)

  train_loss_list.append(avg_loss)

  if i % 1 == 0:
        print("\nEpoch %d Train: Loss %.3f / Accuracy %.3f"%(i,avg_loss,acc))

  # test
  model.eval()

  total_loss = 0
  count = 0

  with torch.no_grad():
    for batch_idx, (x, y) in enumerate(test_loader):
      x, y = x.to(device), y.to(device)
      y_est = model.forward(x)
      cost = loss(y_est, y)

      total_loss += cost.item()

      pred = torch.argmax(y_est, dim = -1)
      count += (pred == y).sum().item()

    acc = count / len(test_data)
    avg_loss = total_loss / len(test_data)

    test_loss_list.append(avg_loss)

    if i % 1 == 0:
      print("Epoch %d Test: Loss %.3f / Accuracy %.3f"%(i,avg_loss,acc))
# Out:
# Epoch 0 Train: Loss 4.331 / Accuracy 0.035
# Epoch 0 Test: Loss 4.031 / Accuracy 0.068
#
# Epoch 1 Train: Loss 3.954 / Accuracy 0.078
# Epoch 1 Test: Loss 3.703 / Accuracy 0.124
#
# Epoch 2 Train: Loss 3.741 / Accuracy 0.115
# Epoch 2 Test: Loss 3.511 / Accuracy 0.162
#
# Epoch 3 Train: Loss 3.556 / Accuracy 0.145
# Epoch 3 Test: Loss 3.328 / Accuracy 0.200
#
# Epoch 4 Train: Loss 3.426 / Accuracy 0.170
# Epoch 4 Test: Loss 3.237 / Accuracy 0.220
#
# Epoch 5 Train: Loss 3.312 / Accuracy 0.191
# Epoch 5 Test: Loss 3.166 / Accuracy 0.235
#
# Epoch 6 Train: Loss 3.208 / Accuracy 0.209
# Epoch 6 Test: Loss 3.050 / Accuracy 0.253
#
# Epoch 7 Train: Loss 3.116 / Accuracy 0.228
# Epoch 7 Test: Loss 2.956 / Accuracy 0.270
#
# Epoch 8 Train: Loss 3.020 / Accuracy 0.246
# Epoch 8 Test: Loss 2.937 / Accuracy 0.275
#
# Epoch 9 Train: Loss 2.948 / Accuracy 0.260
# Epoch 9 Test: Loss 2.848 / Accuracy 0.298
#
# Epoch 10 Train: Loss 2.871 / Accuracy 0.275
# Epoch 10 Test: Loss 2.816 / Accuracy 0.304
#
# Epoch 11 Train: Loss 2.796 / Accuracy 0.284
# Epoch 11 Test: Loss 2.796 / Accuracy 0.303
#
# Epoch 12 Train: Loss 2.737 / Accuracy 0.297
# Epoch 12 Test: Loss 2.749 / Accuracy 0.312
#
# Epoch 13 Train: Loss 2.666 / Accuracy 0.312
# Epoch 13 Test: Loss 2.704 / Accuracy 0.326
#
# Epoch 14 Train: Loss 2.606 / Accuracy 0.323
# Epoch 14 Test: Loss 2.672 / Accuracy 0.333
#
# Epoch 15 Train: Loss 2.552 / Accuracy 0.333
# Epoch 15 Test: Loss 2.691 / Accuracy 0.329
#
# Epoch 16 Train: Loss 2.498 / Accuracy 0.347
# Epoch 16 Test: Loss 2.653 / Accuracy 0.339
#
# Epoch 17 Train: Loss 2.442 / Accuracy 0.354
# Epoch 17 Test: Loss 2.664 / Accuracy 0.339
#
# Epoch 18 Train: Loss 2.392 / Accuracy 0.363
# Epoch 18 Test: Loss 2.645 / Accuracy 0.337
#
# Epoch 19 Train: Loss 2.346 / Accuracy 0.372
# Epoch 19 Test: Loss 2.629 / Accuracy 0.342
#
# Epoch 20 Train: Loss 2.309 / Accuracy 0.380
# Epoch 20 Test: Loss 2.642 / Accuracy 0.343
#
# Epoch 21 Train: Loss 2.257 / Accuracy 0.391
# Epoch 21 Test: Loss 2.634 / Accuracy 0.353
#
# Epoch 22 Train: Loss 2.228 / Accuracy 0.398
# Epoch 22 Test: Loss 2.620 / Accuracy 0.349
#
# Epoch 23 Train: Loss 2.179 / Accuracy 0.409
# Epoch 23 Test: Loss 2.637 / Accuracy 0.352
#
# Epoch 24 Train: Loss 2.151 / Accuracy 0.412
# Epoch 24 Test: Loss 2.620 / Accuracy 0.362
#
# Epoch 25 Train: Loss 2.114 / Accuracy 0.420
# Epoch 25 Test: Loss 2.651 / Accuracy 0.357
#
# Epoch 26 Train: Loss 2.077 / Accuracy 0.429
# Epoch 26 Test: Loss 2.677 / Accuracy 0.355
#
# Epoch 27 Train: Loss 2.053 / Accuracy 0.436
# Epoch 27 Test: Loss 2.664 / Accuracy 0.360
#
# Epoch 28 Train: Loss 2.016 / Accuracy 0.441
# Epoch 28 Test: Loss 2.693 / Accuracy 0.357
#
# Epoch 29 Train: Loss 1.991 / Accuracy 0.446
# Epoch 29 Test: Loss 2.664 / Accuracy 0.364
#
# Epoch 30 Train: Loss 1.966 / Accuracy 0.454
# Epoch 30 Test: Loss 2.697 / Accuracy 0.353
#
# Epoch 31 Train: Loss 1.928 / Accuracy 0.460
# Epoch 31 Test: Loss 2.723 / Accuracy 0.359
#
# Epoch 32 Train: Loss 1.901 / Accuracy 0.464
# Epoch 32 Test: Loss 2.717 / Accuracy 0.357
#
# Epoch 33 Train: Loss 1.885 / Accuracy 0.473
# Epoch 33 Test: Loss 2.712 / Accuracy 0.366
#
# Epoch 34 Train: Loss 1.855 / Accuracy 0.476
# Epoch 34 Test: Loss 2.748 / Accuracy 0.357
#
# Epoch 35 Train: Loss 1.851 / Accuracy 0.480
# Epoch 35 Test: Loss 2.732 / Accuracy 0.365
#
# Epoch 36 Train: Loss 1.824 / Accuracy 0.484
# Epoch 36 Test: Loss 2.748 / Accuracy 0.357
#
# Epoch 37 Train: Loss 1.799 / Accuracy 0.494
# Epoch 37 Test: Loss 2.766 / Accuracy 0.368
#
# Epoch 38 Train: Loss 1.782 / Accuracy 0.497
# Epoch 38 Test: Loss 2.798 / Accuracy 0.365
#
# Epoch 39 Train: Loss 1.753 / Accuracy 0.503
# Epoch 39 Test: Loss 2.799 / Accuracy 0.367
#
# Epoch 40 Train: Loss 1.730 / Accuracy 0.506
# Epoch 40 Test: Loss 2.811 / Accuracy 0.366
#
# Epoch 41 Train: Loss 1.713 / Accuracy 0.512
# Epoch 41 Test: Loss 2.785 / Accuracy 0.364
#
# Epoch 42 Train: Loss 1.689 / Accuracy 0.518
# Epoch 42 Test: Loss 2.815 / Accuracy 0.364
#
# Epoch 43 Train: Loss 1.693 / Accuracy 0.514
# Epoch 43 Test: Loss 2.804 / Accuracy 0.365
#
# Epoch 44 Train: Loss 1.672 / Accuracy 0.524
# Epoch 44 Test: Loss 2.829 / Accuracy 0.365
#
# Epoch 45 Train: Loss 1.647 / Accuracy 0.528
# Epoch 45 Test: Loss 2.882 / Accuracy 0.358
#
# Epoch 46 Train: Loss 1.639 / Accuracy 0.531
# Epoch 46 Test: Loss 2.879 / Accuracy 0.362
#
# Epoch 47 Train: Loss 1.619 / Accuracy 0.534
# Epoch 47 Test: Loss 2.876 / Accuracy 0.369
#
# Epoch 48 Train: Loss 1.604 / Accuracy 0.539
# Epoch 48 Test: Loss 2.895 / Accuracy 0.367
#
# Epoch 49 Train: Loss 1.606 / Accuracy 0.538
# Epoch 49 Test: Loss 2.954 / Accuracy 0.361
#
# Epoch 50 Train: Loss 1.585 / Accuracy 0.545
# Epoch 50 Test: Loss 2.886 / Accuracy 0.359
#
# Epoch 51 Train: Loss 1.564 / Accuracy 0.550
# Epoch 51 Test: Loss 2.912 / Accuracy 0.364
#
# Epoch 52 Train: Loss 1.569 / Accuracy 0.548
# Epoch 52 Test: Loss 2.931 / Accuracy 0.362
#
# Epoch 53 Train: Loss 1.552 / Accuracy 0.552
# Epoch 53 Test: Loss 2.922 / Accuracy 0.363
#
# Epoch 54 Train: Loss 1.533 / Accuracy 0.558
# Epoch 54 Test: Loss 2.968 / Accuracy 0.365
#
# Epoch 55 Train: Loss 1.525 / Accuracy 0.561
# Epoch 55 Test: Loss 2.921 / Accuracy 0.365
#
# Epoch 56 Train: Loss 1.515 / Accuracy 0.562
# Epoch 56 Test: Loss 2.992 / Accuracy 0.365
#
# Epoch 57 Train: Loss 1.489 / Accuracy 0.570
# Epoch 57 Test: Loss 2.939 / Accuracy 0.360
#
# Epoch 58 Train: Loss 1.493 / Accuracy 0.569
# Epoch 58 Test: Loss 2.974 / Accuracy 0.364
#
# Epoch 59 Train: Loss 1.477 / Accuracy 0.572
# Epoch 59 Test: Loss 2.906 / Accuracy 0.361
#
# Epoch 60 Train: Loss 1.469 / Accuracy 0.573
# Epoch 60 Test: Loss 3.021 / Accuracy 0.369
#
# Epoch 61 Train: Loss 1.456 / Accuracy 0.580
# Epoch 61 Test: Loss 3.004 / Accuracy 0.362
#
# Epoch 62 Train: Loss 1.443 / Accuracy 0.582
# Epoch 62 Test: Loss 3.037 / Accuracy 0.367
#
# Epoch 63 Train: Loss 1.436 / Accuracy 0.581
# Epoch 63 Test: Loss 3.000 / Accuracy 0.365
#
# Epoch 64 Train: Loss 1.422 / Accuracy 0.587
# Epoch 64 Test: Loss 3.058 / Accuracy 0.361
#
# Epoch 65 Train: Loss 1.413 / Accuracy 0.591
# Epoch 65 Test: Loss 3.030 / Accuracy 0.367
#
# Epoch 66 Train: Loss 1.421 / Accuracy 0.588
# Epoch 66 Test: Loss 3.087 / Accuracy 0.359
#
# Epoch 67 Train: Loss 1.394 / Accuracy 0.595
# Epoch 67 Test: Loss 3.060 / Accuracy 0.367
#
# Epoch 68 Train: Loss 1.385 / Accuracy 0.595
# Epoch 68 Test: Loss 3.096 / Accuracy 0.364
#
# Epoch 69 Train: Loss 1.386 / Accuracy 0.599
# Epoch 69 Test: Loss 3.080 / Accuracy 0.365
#
# Epoch 70 Train: Loss 1.394 / Accuracy 0.597
# Epoch 70 Test: Loss 3.003 / Accuracy 0.363
#
# Epoch 71 Train: Loss 1.367 / Accuracy 0.603
# Epoch 71 Test: Loss 3.104 / Accuracy 0.366
#
# Epoch 72 Train: Loss 1.366 / Accuracy 0.605
# Epoch 72 Test: Loss 3.057 / Accuracy 0.368
#
# Epoch 73 Train: Loss 1.356 / Accuracy 0.608
# Epoch 73 Test: Loss 3.219 / Accuracy 0.369
#
# Epoch 74 Train: Loss 1.340 / Accuracy 0.612
# Epoch 74 Test: Loss 3.166 / Accuracy 0.364
#
# Epoch 75 Train: Loss 1.344 / Accuracy 0.612
# Epoch 75 Test: Loss 3.130 / Accuracy 0.365
#
# Epoch 76 Train: Loss 1.330 / Accuracy 0.612
# Epoch 76 Test: Loss 3.120 / Accuracy 0.371
#
# Epoch 77 Train: Loss 1.340 / Accuracy 0.612
# Epoch 77 Test: Loss 3.148 / Accuracy 0.367
#
# Epoch 78 Train: Loss 1.320 / Accuracy 0.615
# Epoch 78 Test: Loss 3.087 / Accuracy 0.369
#
# Epoch 79 Train: Loss 1.308 / Accuracy 0.621
# Epoch 79 Test: Loss 3.192 / Accuracy 0.364
#
# Epoch 80 Train: Loss 1.313 / Accuracy 0.618
# Epoch 80 Test: Loss 3.108 / Accuracy 0.370
#
# Epoch 81 Train: Loss 1.301 / Accuracy 0.624
# Epoch 81 Test: Loss 3.172 / Accuracy 0.374
#
# Epoch 82 Train: Loss 1.294 / Accuracy 0.625
# Epoch 82 Test: Loss 3.215 / Accuracy 0.373
#
# Epoch 83 Train: Loss 1.279 / Accuracy 0.631
# Epoch 83 Test: Loss 3.157 / Accuracy 0.368
#
# Epoch 84 Train: Loss 1.273 / Accuracy 0.630
# Epoch 84 Test: Loss 3.172 / Accuracy 0.366
#
# Epoch 85 Train: Loss 1.276 / Accuracy 0.629
# Epoch 85 Test: Loss 3.137 / Accuracy 0.369
#
# Epoch 86 Train: Loss 1.278 / Accuracy 0.628
# Epoch 86 Test: Loss 3.171 / Accuracy 0.372
#
# Epoch 87 Train: Loss 1.246 / Accuracy 0.638
# Epoch 87 Test: Loss 3.204 / Accuracy 0.368
#
# Epoch 88 Train: Loss 1.246 / Accuracy 0.638
# Epoch 88 Test: Loss 3.223 / Accuracy 0.372
#
# Epoch 89 Train: Loss 1.251 / Accuracy 0.635
# Epoch 89 Test: Loss 3.215 / Accuracy 0.370
#
# Epoch 90 Train: Loss 1.242 / Accuracy 0.639
# Epoch 90 Test: Loss 3.264 / Accuracy 0.365
#
# Epoch 91 Train: Loss 1.228 / Accuracy 0.642
# Epoch 91 Test: Loss 3.340 / Accuracy 0.364
#
# Epoch 92 Train: Loss 1.238 / Accuracy 0.641
# Epoch 92 Test: Loss 3.279 / Accuracy 0.363
#
# Epoch 93 Train: Loss 1.221 / Accuracy 0.644
# Epoch 93 Test: Loss 3.289 / Accuracy 0.366
#
# Epoch 94 Train: Loss 1.235 / Accuracy 0.641
# Epoch 94 Test: Loss 3.254 / Accuracy 0.365
#
# Epoch 95 Train: Loss 1.226 / Accuracy 0.646
# Epoch 95 Test: Loss 3.315 / Accuracy 0.368
#
# Epoch 96 Train: Loss 1.215 / Accuracy 0.647
# Epoch 96 Test: Loss 3.181 / Accuracy 0.366
#
# Epoch 97 Train: Loss 1.208 / Accuracy 0.646
# Epoch 97 Test: Loss 3.337 / Accuracy 0.367
#
# Epoch 98 Train: Loss 1.192 / Accuracy 0.652
# Epoch 98 Test: Loss 3.351 / Accuracy 0.366
#
# Epoch 99 Train: Loss 1.216 / Accuracy 0.648
# Epoch 99 Test: Loss 3.367 / Accuracy 0.362
#
# Epoch 100 Train: Loss 1.201 / Accuracy 0.650
# Epoch 100 Test: Loss 3.298 / Accuracy 0.369
#
# Epoch 101 Train: Loss 1.199 / Accuracy 0.653
# Epoch 101 Test: Loss 3.357 / Accuracy 0.369
#
# Epoch 102 Train: Loss 1.186 / Accuracy 0.656
# Epoch 102 Test: Loss 3.287 / Accuracy 0.369
#
# Epoch 103 Train: Loss 1.177 / Accuracy 0.661
# Epoch 103 Test: Loss 3.352 / Accuracy 0.368
#
# Epoch 104 Train: Loss 1.188 / Accuracy 0.658
# Epoch 104 Test: Loss 3.380 / Accuracy 0.366
#
# Epoch 105 Train: Loss 1.175 / Accuracy 0.660
# Epoch 105 Test: Loss 3.430 / Accuracy 0.360
#
# Epoch 106 Train: Loss 1.182 / Accuracy 0.659
# Epoch 106 Test: Loss 3.340 / Accuracy 0.361
#
# Epoch 107 Train: Loss 1.149 / Accuracy 0.665
# Epoch 107 Test: Loss 3.388 / Accuracy 0.363
#
# Epoch 108 Train: Loss 1.157 / Accuracy 0.666
# Epoch 108 Test: Loss 3.371 / Accuracy 0.366
#
# Epoch 109 Train: Loss 1.162 / Accuracy 0.661
# Epoch 109 Test: Loss 3.303 / Accuracy 0.365
#
# Epoch 110 Train: Loss 1.147 / Accuracy 0.667
# Epoch 110 Test: Loss 3.317 / Accuracy 0.367
#
# Epoch 111 Train: Loss 1.143 / Accuracy 0.670
# Epoch 111 Test: Loss 3.395 / Accuracy 0.367
#
# Epoch 112 Train: Loss 1.132 / Accuracy 0.672
# Epoch 112 Test: Loss 3.334 / Accuracy 0.367
#
# Epoch 113 Train: Loss 1.137 / Accuracy 0.669
# Epoch 113 Test: Loss 3.395 / Accuracy 0.366
#
# Epoch 114 Train: Loss 1.137 / Accuracy 0.672
# Epoch 114 Test: Loss 3.440 / Accuracy 0.367
#
# Epoch 115 Train: Loss 1.131 / Accuracy 0.672
# Epoch 115 Test: Loss 3.371 / Accuracy 0.368
#
# Epoch 116 Train: Loss 1.126 / Accuracy 0.672
# Epoch 116 Test: Loss 3.370 / Accuracy 0.365
#
# Epoch 117 Train: Loss 1.122 / Accuracy 0.673
# Epoch 117 Test: Loss 3.414 / Accuracy 0.365
#
# Epoch 118 Train: Loss 1.119 / Accuracy 0.676
# Epoch 118 Test: Loss 3.386 / Accuracy 0.359
#
# Epoch 119 Train: Loss 1.120 / Accuracy 0.674
# Epoch 119 Test: Loss 3.348 / Accuracy 0.365
#
# Epoch 120 Train: Loss 1.105 / Accuracy 0.677
# Epoch 120 Test: Loss 3.427 / Accuracy 0.359
#
# Epoch 121 Train: Loss 1.121 / Accuracy 0.676
# Epoch 121 Test: Loss 3.463 / Accuracy 0.366
#
# Epoch 122 Train: Loss 1.116 / Accuracy 0.676
# Epoch 122 Test: Loss 3.423 / Accuracy 0.361
#
# Epoch 123 Train: Loss 1.095 / Accuracy 0.682
# Epoch 123 Test: Loss 3.491 / Accuracy 0.363
#
# Epoch 124 Train: Loss 1.095 / Accuracy 0.681
# Epoch 124 Test: Loss 3.414 / Accuracy 0.363
#
# Epoch 125 Train: Loss 1.095 / Accuracy 0.683
# Epoch 125 Test: Loss 3.374 / Accuracy 0.365
#
# Epoch 126 Train: Loss 1.102 / Accuracy 0.682
# Epoch 126 Test: Loss 3.408 / Accuracy 0.362
#
# Epoch 127 Train: Loss 1.088 / Accuracy 0.683
# Epoch 127 Test: Loss 3.507 / Accuracy 0.363
#
# Epoch 128 Train: Loss 1.082 / Accuracy 0.686
# Epoch 128 Test: Loss 3.418 / Accuracy 0.362
#
# Epoch 129 Train: Loss 1.085 / Accuracy 0.687
# Epoch 129 Test: Loss 3.452 / Accuracy 0.363
#
# Epoch 130 Train: Loss 1.085 / Accuracy 0.687
# Epoch 130 Test: Loss 3.525 / Accuracy 0.366
#
# Epoch 131 Train: Loss 1.085 / Accuracy 0.686
# Epoch 131 Test: Loss 3.449 / Accuracy 0.359
#
# Epoch 132 Train: Loss 1.067 / Accuracy 0.691
# Epoch 132 Test: Loss 3.609 / Accuracy 0.367
#
# Epoch 133 Train: Loss 1.062 / Accuracy 0.692
# Epoch 133 Test: Loss 3.602 / Accuracy 0.363
#
# Epoch 134 Train: Loss 1.071 / Accuracy 0.689
# Epoch 134 Test: Loss 3.517 / Accuracy 0.360
#
# Epoch 135 Train: Loss 1.074 / Accuracy 0.691
# Epoch 135 Test: Loss 3.619 / Accuracy 0.362
#
# Epoch 136 Train: Loss 1.068 / Accuracy 0.694
# Epoch 136 Test: Loss 3.575 / Accuracy 0.366
#
# Epoch 137 Train: Loss 1.071 / Accuracy 0.690
# Epoch 137 Test: Loss 3.469 / Accuracy 0.363
#
# Epoch 138 Train: Loss 1.061 / Accuracy 0.694
# Epoch 138 Test: Loss 3.573 / Accuracy 0.364
#
# Epoch 139 Train: Loss 1.065 / Accuracy 0.693
# Epoch 139 Test: Loss 3.474 / Accuracy 0.364
#
# Epoch 140 Train: Loss 1.054 / Accuracy 0.697
# Epoch 140 Test: Loss 3.617 / Accuracy 0.361
#
# Epoch 141 Train: Loss 1.053 / Accuracy 0.696
# Epoch 141 Test: Loss 3.497 / Accuracy 0.365
#
# Epoch 142 Train: Loss 1.043 / Accuracy 0.699
# Epoch 142 Test: Loss 3.600 / Accuracy 0.363
#
# Epoch 143 Train: Loss 1.040 / Accuracy 0.699
# Epoch 143 Test: Loss 3.609 / Accuracy 0.365
#
# Epoch 144 Train: Loss 1.052 / Accuracy 0.696
# Epoch 144 Test: Loss 3.665 / Accuracy 0.363
#
# Epoch 145 Train: Loss 1.047 / Accuracy 0.698
# Epoch 145 Test: Loss 3.633 / Accuracy 0.361
#
# Epoch 146 Train: Loss 1.034 / Accuracy 0.702
# Epoch 146 Test: Loss 3.605 / Accuracy 0.361
#
# Epoch 147 Train: Loss 1.040 / Accuracy 0.702
# Epoch 147 Test: Loss 3.637 / Accuracy 0.364
#
# Epoch 148 Train: Loss 1.018 / Accuracy 0.704
# Epoch 148 Test: Loss 3.565 / Accuracy 0.358
#
# Epoch 149 Train: Loss 1.042 / Accuracy 0.702
# Epoch 149 Test: Loss 3.570 / Accuracy 0.367

# %%
num_parameter = 0

for parameter in model.parameters():
  print(parameter.shape)
  num_parameter += np.prod(parameter.size())
print(num_parameter)
# Out:
# torch.Size([18, 3, 5, 5])
# torch.Size([18])
# torch.Size([48, 18, 5, 5])
# torch.Size([48])
# torch.Size([512, 1728])
# torch.Size([512])
# torch.Size([256, 512])
# torch.Size([256])
# torch.Size([128, 256])
# torch.Size([128])
# torch.Size([100, 128])
# torch.Size([100])
# 1085388
